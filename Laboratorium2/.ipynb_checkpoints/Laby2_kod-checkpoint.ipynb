# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("baboon.png")

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
h = img.shape[0]
w = img.shape[1]

# %%
cv2.circle(img, (70, 70), 60, (0, 0, 255), 3)
cv2.rectangle(img, (200, 200), (350, 350), (0, 255, 0), -1)
cv2.ellipse(img, (350, 450), (100, 20), 0, 0, 360, (0, 255, 255), -1)

# %%
cv2.imwrite("figury.png", img)
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
